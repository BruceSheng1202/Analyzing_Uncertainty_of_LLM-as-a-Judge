# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm
from statsmodels.stats.diagnostic import het_breuschpagan, het_white

def heteroskedasticity_hypothesis_testing(X,y):
        X_with_const = sm.add_constant(X)
        model = sm.OLS(y, X_with_const).fit()
        resid = model.resid
        exog = model.model.exog
        bp_stat = het_breuschpagan(resid, exog)
        bp_labels = ['LM Statistic', 'LM p-value', 'F Statistic', 'F p-value']
        bp_results = dict(zip(bp_labels, bp_stat))
        white_stat = het_white(resid, exog)
        white_labels = ['LM Statistic', 'LM p-value', 'F Statistic', 'F p-value']
        white_results = dict(zip(white_labels, white_stat))
        results_df = pd.DataFrame([bp_results, white_results], index=['Breusch-Pagan', 'White'])
        return results_df

# %%
import os
import pandas as pd

for dataset in {'Summeval', 'Dialsumm', 'SocREval', 'GEval'}:
        for model in {'4omini', 'dsr1', 'qwen'}:
                folder_path = f'./model_logits/{model}/'
                if dataset == 'Summeval' or dataset == 'Dialsumm':
                        dimensions = ['consistency', 'coherence', 'fluency', 'relevance']
                elif dataset == 'GEval' or dataset == 'SocREval':
                        dimensions = ['cosmos', 'drop', 'esnli', 'gsm8k']
                for dimension in dimensions:
                        file_path = os.path.join(folder_path, f"{dataset}_{dimension}_logits.csv")
                        df = pd.read_csv(file_path)
                        X = df.iloc[:, :-1]
                        y = df.iloc[:, -1]
                        ht_result = heteroskedasticity_hypothesis_testing(X,y)
                        print(f"The hypothesis testing results of {dataset}_{dimension} from {model}: ")
                        print(ht_result)
# Out:
# The hypothesis testing results of GEval_cosmos from qwen:
#                LM Statistic  LM p-value  F Statistic  F p-value
# Breusch-Pagan      7.883014    0.162802     1.592469   0.164083
# White             25.904197    0.168999     1.332774   0.163982
# The hypothesis testing results of GEval_drop from qwen:
#                LM Statistic  LM p-value  F Statistic  F p-value
# Breusch-Pagan     22.042249    0.000514     4.784712   0.000371
# White             31.325569    0.051036     1.656793   0.043809
# The hypothesis testing results of GEval_esnli from qwen:
#                LM Statistic  LM p-value  F Statistic  F p-value
# Breusch-Pagan     22.553662    0.000411     5.092058   0.000248
# White             49.770427    0.000239     3.195783   0.000036
# The hypothesis testing results of GEval_gsm8k from qwen:
#                LM Statistic  LM p-value  F Statistic  F p-value
# Breusch-Pagan     27.782255    0.000040     6.259236   0.000021
# White             56.738744    0.000022     3.544655   0.000003
# The hypothesis testing results of GEval_cosmos from 4omini:
#                LM Statistic  LM p-value  F Statistic  F p-value
# Breusch-Pagan      5.839344    0.322167     1.166877   0.327039
# White             17.193518    0.640374     0.841272   0.660954
# The hypothesis testing results of GEval_drop from 4omini:
#                LM Statistic  LM p-value  F Statistic  F p-value
# Breusch-Pagan     11.334077    0.045144     2.327678   0.043982
# White             23.456310    0.266948     1.188259   0.268124
# The hypothesis testing results of GEval_esnli from 4omini:
#                LM Statistic  LM p-value  F Statistic  F p-value
# Breusch-Pagan     26.073547    0.000086     6.052624   0.000040
# White             35.173953    0.019197     1.973914   0.012443
# The hypothesis testing results of GEval_gsm8k from 4omini:
#                LM Statistic  LM p-value  F Statistic  F p-value
# Breusch-Pagan      7.586168    0.180566     1.529741   0.182247
# White             26.150783    0.160890     1.346279   0.155589
# The hypothesis testing results of GEval_cosmos from dsr1:
#                LM Statistic  LM p-value  F Statistic  F p-value
# Breusch-Pagan      8.041965    0.153938     1.625960   0.154996
# White             17.669802    0.609150     0.866898   0.629023
# The hypothesis testing results of GEval_drop from dsr1:
#                LM Statistic  LM p-value  F Statistic  F p-value
# Breusch-Pagan     20.313195    0.001091     4.369194   0.000844
# White             40.833344    0.003913     2.281035   0.002200
# The hypothesis testing results of GEval_esnli from dsr1:
#                LM Statistic  LM p-value  F Statistic     F p-value
# Breusch-Pagan     24.209122    0.000198     5.537185  1.069259e-04
# White             58.598038    0.000012     4.122069  3.809132e-07
# The hypothesis testing results of GEval_gsm8k from dsr1:
#                LM Statistic  LM p-value  F Statistic  F p-value
# Breusch-Pagan     15.827957    0.007353     3.334517   0.006517
# White             33.871940    0.027004     1.824820   0.020957
# The hypothesis testing results of Dialsumm_consistency from qwen:
#                LM Statistic    LM p-value  F Statistic     F p-value
# Breusch-Pagan     88.781510  1.211249e-17    18.877315  3.370238e-18
# White            123.891957  5.400126e-17     6.694065  7.130019e-18
# The hypothesis testing results of Dialsumm_coherence from qwen:
#                LM Statistic    LM p-value  F Statistic     F p-value
# Breusch-Pagan    209.550513  2.568258e-43    49.076155  6.756458e-47
# White            228.973780  1.919674e-37    13.481971  3.085306e-41
# The hypothesis testing results of Dialsumm_fluency from qwen:
#                LM Statistic    LM p-value  F Statistic     F p-value
# Breusch-Pagan    199.736536  3.234253e-41    46.395269  1.923138e-44
# White            235.628431  8.894898e-39    13.953089  7.829170e-43
# The hypothesis testing results of Dialsumm_relevance from qwen:
#                LM Statistic    LM p-value  F Statistic     F p-value
# Breusch-Pagan    125.826626  1.827619e-25    27.531939  1.189336e-26
# White            175.737420  6.609488e-27     9.897464  6.011615e-29
# The hypothesis testing results of Dialsumm_consistency from 4omini:
#                LM Statistic    LM p-value  F Statistic     F p-value
# Breusch-Pagan     70.219990  9.222563e-14    14.723256  4.297531e-14
# White             96.249577  5.871405e-12     5.090671  2.011613e-12
# The hypothesis testing results of Dialsumm_coherence from 4omini:
#                LM Statistic    LM p-value  F Statistic     F p-value
# Breusch-Pagan    199.049793  4.536040e-41    46.209312  2.850587e-44
# White            238.533460  2.321602e-39    14.160444  1.560086e-43
# The hypothesis testing results of Dialsumm_fluency from 4omini:
#                LM Statistic    LM p-value  F Statistic     F p-value
# Breusch-Pagan    250.632601  4.021473e-52    60.795503  2.063535e-57
# White            271.824121  4.397617e-46    16.612900  9.799981e-52
# The hypothesis testing results of Dialsumm_relevance from 4omini:
#                LM Statistic    LM p-value  F Statistic     F p-value
# Breusch-Pagan     87.824847  1.923404e-17    18.663638  5.494232e-18
# White            170.231149  7.815816e-26     9.547796  9.861960e-28
# The hypothesis testing results of Dialsumm_consistency from dsr1:
#                LM Statistic    LM p-value  F Statistic     F p-value
# Breusch-Pagan    100.157615  4.895953e-20    21.482561  9.264927e-21
# White            169.038993  1.332694e-25     9.468406  1.832058e-27
# The hypothesis testing results of Dialsumm_coherence from dsr1:
#                LM Statistic    LM p-value  F Statistic     F p-value
# Breusch-Pagan    126.174293  1.542269e-25    27.615546  9.873419e-27
# White            196.532141  5.453756e-31    11.259870  1.205257e-33
# The hypothesis testing results of Dialsumm_fluency from dsr1:
#                LM Statistic    LM p-value  F Statistic     F p-value
# Breusch-Pagan    169.679683  8.539729e-35    38.450715  4.632589e-37
# White            225.734627  8.539524e-37    13.254587  1.825080e-40
# The hypothesis testing results of Dialsumm_relevance from dsr1:
#                LM Statistic    LM p-value  F Statistic     F p-value
# Breusch-Pagan    177.728445  1.635019e-36    40.539838  5.115351e-39
# White            250.758500  8.031903e-42    15.044530  1.653012e-46
# The hypothesis testing results of Summeval_consistency from qwen:
#                LM Statistic    LM p-value  F Statistic     F p-value
# Breusch-Pagan    351.774986  7.260176e-74    89.844270  2.029941e-83
# White            407.694695  5.172651e-74    26.996019  2.327194e-86
# The hypothesis testing results of Summeval_coherence from qwen:
#                LM Statistic    LM p-value  F Statistic     F p-value
# Breusch-Pagan     82.247739  2.840387e-16    17.275928  1.107988e-16
# White            142.134092  1.990923e-20     7.697201  1.712676e-21
# The hypothesis testing results of Summeval_fluency from qwen:
#                LM Statistic    LM p-value  F Statistic     F p-value
# Breusch-Pagan    227.916530  2.990478e-47    52.955809  5.937710e-51
# White            245.422719  9.552516e-41    14.304185  1.404586e-44
# The hypothesis testing results of Summeval_relevance from qwen:
#                LM Statistic    LM p-value  F Statistic     F p-value
# Breusch-Pagan     83.830161  1.323970e-16    17.626690  4.961172e-17
# White            100.687554  9.486408e-13     5.301952  3.339193e-13
# The hypothesis testing results of Summeval_consistency from 4omini:
#                LM Statistic    LM p-value  F Statistic     F p-value
# Breusch-Pagan    372.120822  3.015306e-78    96.615465  4.524011e-89
# White            446.358789  4.680976e-82    30.546782  2.607386e-97
# The hypothesis testing results of Summeval_coherence from 4omini:
#                LM Statistic    LM p-value  F Statistic     F p-value
# Breusch-Pagan    147.034249  5.710782e-30    32.261269  2.072388e-31
# White            204.285121  1.595018e-32    11.555591  4.956963e-35
# The hypothesis testing results of Summeval_fluency from 4omini:
#                LM Statistic    LM p-value  F Statistic     F p-value
# Breusch-Pagan    144.954399  1.581885e-29    31.759460  6.345048e-31
# White            187.021063  4.076528e-29    10.449776  3.707114e-31
# The hypothesis testing results of Summeval_relevance from 4omini:
#                LM Statistic    LM p-value  F Statistic     F p-value
# Breusch-Pagan    102.859634  1.318574e-20    21.902857  2.845697e-21
# White            132.282032  1.452678e-18     7.115581  1.848296e-19
# The hypothesis testing results of Summeval_consistency from dsr1:
#                LM Statistic    LM p-value  F Statistic     F p-value
# Breusch-Pagan    332.233609  1.167584e-69    83.545419  4.439278e-78
# White            406.727679  8.212269e-74    26.910161  4.320892e-86
# The hypothesis testing results of Summeval_coherence from dsr1:
#                LM Statistic    LM p-value  F Statistic     F p-value
# Breusch-Pagan     64.602028  1.355324e-12    13.413543  7.807208e-13
# White            142.665712  1.577540e-20     7.728809  1.327350e-21
# The hypothesis testing results of Summeval_fluency from dsr1:
#                LM Statistic    LM p-value  F Statistic     F p-value
# Breusch-Pagan    209.266174  2.954650e-43    47.970399  2.464396e-46
# White            242.605875  3.524185e-40    14.110665  6.532661e-44
# The hypothesis testing results of Summeval_relevance from dsr1:
#                LM Statistic    LM p-value  F Statistic     F p-value
# Breusch-Pagan     78.493549  1.733415e-15    16.446689  7.412408e-16
# White             92.448089  2.758051e-11     4.841476  1.194291e-11
# The hypothesis testing results of SocREval_cosmos from qwen:
#                LM Statistic  LM p-value  F Statistic  F p-value
# Breusch-Pagan     13.470195    0.019349     2.804902   0.018102
# White             34.355738    0.007551     2.226683   0.004995
# The hypothesis testing results of SocREval_drop from qwen:
#                LM Statistic  LM p-value  F Statistic  F p-value
# Breusch-Pagan      8.464056    0.132447     1.713508   0.132934
# White             22.780376    0.199171     1.291131   0.197061
# The hypothesis testing results of SocREval_esnli from qwen:
#                LM Statistic  LM p-value  F Statistic  F p-value
# Breusch-Pagan     16.545020    0.005449     3.568522   0.004502
# White             29.925664    0.038175     1.812563   0.029808
# The hypothesis testing results of SocREval_gsm8k from qwen:
#                LM Statistic  LM p-value  F Statistic  F p-value
# Breusch-Pagan      2.321358    0.803125     0.455632   0.808859
# White             12.387373    0.776134     0.706870   0.793450
# The hypothesis testing results of SocREval_cosmos from 4omini:
#                LM Statistic  LM p-value  F Statistic  F p-value
# Breusch-Pagan      7.255622    0.202313     1.460829   0.204572
# White             20.130322    0.267618     1.198562   0.269732
# The hypothesis testing results of SocREval_drop from 4omini:
#                LM Statistic  LM p-value  F Statistic  F p-value
# Breusch-Pagan      4.016426    0.547054     0.795550   0.553989
# White             37.300928    0.010767     2.041087   0.007315
# The hypothesis testing results of SocREval_esnli from 4omini:
#                LM Statistic  LM p-value  F Statistic  F p-value
# Breusch-Pagan      7.636869    0.177417     1.544813   0.179542
# White             12.765716    0.751723     0.722491   0.775461
# The hypothesis testing results of SocREval_gsm8k from 4omini:
#                LM Statistic  LM p-value  F Statistic  F p-value
# Breusch-Pagan      3.576814    0.611798     0.706538   0.619177
# White             11.660903    0.820222     0.662848   0.836260
# The hypothesis testing results of SocREval_cosmos from dsr1:
#                LM Statistic  LM p-value  F Statistic  F p-value
# Breusch-Pagan      5.658754    0.340852     1.129711   0.346064
# White             13.282886    0.864919     0.635940   0.881622
# The hypothesis testing results of SocREval_drop from dsr1:
#                LM Statistic  LM p-value  F Statistic  F p-value
# Breusch-Pagan     29.404097    0.000019     6.642937   0.000009
# White             38.105307    0.008597     2.094859   0.005614
# The hypothesis testing results of SocREval_esnli from dsr1:
#                LM Statistic  LM p-value  F Statistic  F p-value
# Breusch-Pagan      6.994436    0.221054     1.408547   0.224565
# White             18.954797    0.524766     0.933061   0.546936
# The hypothesis testing results of SocREval_gsm8k from dsr1:
#                LM Statistic  LM p-value  F Statistic  F p-value
# Breusch-Pagan      4.243874    0.514865      0.84116   0.521994
# White              8.982514    0.983109      0.42087   0.986777
